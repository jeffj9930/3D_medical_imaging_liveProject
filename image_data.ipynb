# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)

# %%
import os
import nibabel as nib
import matplotlib.pyplot as plt
#image = nib.load("/home/jeff/Documents/ml_files/medical_imaging/small/t1/IXI102-HH-1416-T1_fcm.nii.gz")
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'ml_files/medical_imaging/small/'
im_name = base_dir + "t1/IXI102-HH-1416-T1_fcm.nii.gz"
image = nib.load(im_name)
image_data_t1 = image.get_fdata()

# %%
#image = nib.load("/home/jeff/Documents/ml_files/medical_imaging/small/t2/IXI102-HH-1416-T2_reg_fcm.nii.gz")
im_name = base_dir + "t2/IXI102-HH-1416-T2_reg_fcm.nii.gz"
image = nib.load(im_name)
image_data_t2 = image.get_fdata()

# %%
# Out:
# Mounted at /content/gdrive

# %%
plt.imshow(image_data_t1[80])

# %%
plt.imshow(image_data_t2[80])
